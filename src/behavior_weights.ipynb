# %%
a = (cp.BehaviorSubjects() & 'n_probes = 4')#.fetch('implant_total_weight','fixtures_weight')
a = []
a.append(dict(subject_name='JC194',implant_total_weight = 2.9,
              fixtures_weight = 1.92))
a.append(dict(subject_name='JC195',implant_total_weight = 5.45,
              fixtures_weight = 5.45))
a.append(dict(subject_name='JC196',implant_total_weight = 3.0,
              fixtures_weight = 1.92))
a.append(dict(subject_name='JC197',implant_total_weight = 0.43,
              fixtures_weight = 0))
a.append(dict(subject_name='JC198',implant_total_weight = 5.23,
              fixtures_weight = 3.7))
a.append(dict(subject_name='JC199',implant_total_weight = 2.89,
              fixtures_weight = 1.92))
a.append(dict(subject_name='JC200',implant_total_weight = 5.45,
              fixtures_weight = 3.7))
a.append(dict(subject_name='JC201',implant_total_weight = 4.89,
              fixtures_weight = 3.7))
a.append(dict(subject_name='JC202',implant_total_weight = 2.8,
              fixtures_weight = 1.92))
a.append(dict(subject_name='JC203',implant_total_weight = 0.38,
              fixtures_weight = 0))
a.append(dict(subject_name='JC204',implant_total_weight = 0.27,
              fixtures_weight = 0))
a.append(dict(subject_name='JC205',implant_total_weight = 0.43,
              fixtures_weight = 0))
for aa in a:
  cp.BehaviorSubjects.update1(aa)
